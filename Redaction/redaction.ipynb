# %%
import torch
print(torch.__version__)  # should show +cu118 or +cu121
print("CUDA available:", torch.cuda.is_available())  # should be True if everything is okay
# Out:
# 2.8.0+cpu
# CUDA available: False

# %%
from pathlib import Path

# %%
from typing import List, Dict, Any, Tuple

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe

# %%
import os
from pathlib import Path
import torch
from transformers import pipeline
import matplotlib.pyplot as plt

# %%
# OCR
import pytesseract
from pytesseract import Output

# %%
# Imaging & PDF
from PIL import Image, ImageDraw
import fitz  # PyMuPDF

# %%
# NER
from transformers import pipeline

# %%
# CSV log
import csv
from datetime import datetime

# %%
DEFAULT_NER_MODEL = "dslim/bert-base-NER"  # good general English NER
SUPPORTED_IMAGE_EXTS = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp", ".webp"}

# %%
from dataclasses import dataclass
from typing import Tuple
@dataclass
class RedactionEvent:
    page_index: int
    text: str
    label: str
    score: float
    bbox: Tuple[int, int, int, int]  # (left, top, right, bottom) on page image coords
    line_index: int

# %%
@dataclass
class DocumentSummary:
    input_path: str
    total_pages: int
    total_entities: int
    redacted_entities: int
    sensitivity_score: float
    sensitivity_label: str
    threshold: float
    model_name: str
    generated_at: str

# %%
def load_ner_pipeline(model_name: str = DEFAULT_NER_MODEL):
    return pipeline("token-classification", model=model_name, aggregation_strategy="simple")

# %%
def pdf_to_images(pdf_path: Path, dpi: int = 200) -> List[Image.Image]:
    """Render each PDF page to a PIL Image using PyMuPDF."""
    images = []
    with fitz.open(pdf_path) as doc:
        for page in doc:
            mat = fitz.Matrix(dpi/72, dpi/72)
            pix = page.get_pixmap(matrix=mat, alpha=False)
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
            images.append(img)
    return images

def load_image_any(path: Path) -> Image.Image:
    return Image.open(path).convert("RGB")

def ocr_image_words(img: Image.Image, lang: str = "eng") -> List[Dict[str, Any]]:
    """
    OCR an image and return a list of word dictionaries including:
      - text, conf, left, top, width, height, line_num
    Uses pytesseract.image_to_data to get word-level boxes.
    """
    data = pytesseract.image_to_data(img, lang=lang, output_type=Output.DICT)
    n = len(data["text"])
    words = []
    for i in range(n):
        text = data["text"][i]
        if text is None or text.strip() == "":
            continue
        try:
            conf = float(data["conf"][i])
        except Exception:
            conf = -1.0
        word = {
            "text": text,
            "conf": conf,
            "left": int(data["left"][i]),
            "top": int(data["top"][i]),
            "width": int(data["width"][i]),
            "height": int(data["height"][i]),
            "line_num": int(data.get("line_num", [0]*n)[i]),
            "block_num": int(data.get("block_num", [0]*n)[i]),
            "par_num": int(data.get("par_num", [0]*n)[i]),
        }
        words.append(word)
    return words

# %%
def words_to_lines(words: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Group words by their line_num, preserve order by x-position.
    Returns list of lines: { line_index, text, spans }
    spans: list of {text, bbox, start_char, end_char}
    """
    # group by (block, par, line) to avoid collisions
    from collections import defaultdict
    groups = defaultdict(list)
    for w in words:
        key = (w["block_num"], w["par_num"], w["line_num"])
        groups[key].append(w)

    lines = []
    for idx, (key, ws) in enumerate(sorted(groups.items(), key=lambda kv: (kv[0][0], kv[0][1], kv[0][2]))):
        # sort words left-to-right
        ws_sorted = sorted(ws, key=lambda x: x["left"])
        text_parts = []
        spans = []
        cursor = 0
        for w in ws_sorted:
            word_text = str(w["text"])
            if text_parts:
                # Insert a space between words
                text_parts.append(" ")
                cursor += 1
            start = cursor
            text_parts.append(word_text)
            cursor += len(word_text)
            end = cursor
            bbox = (w["left"], w["top"], w["left"] + w["width"], w["top"] + w["height"])
            spans.append({
                "text": word_text,
                "bbox": bbox,
                "start_char": start,
                "end_char": end,
                "conf": w["conf"],
            })
        lines.append({
            "line_index": idx,
            "text": "".join(text_parts),
            "spans": spans
        })
    return lines

# %%
def align_entity_to_bboxes(entity: Dict[str, Any], line: Dict[str, Any]) -> List[Tuple[int,int,int,int]]:
    """
    Given an entity with 'start'/'end' (char offsets in line) and the line spans,
    return list of bboxes covering the entity.
    """
    start = entity["start"]
    end = entity["end"]
    bboxes = []
    for span in line["spans"]:
        if span["end_char"] <= start or span["start_char"] >= end:
            continue  # no overlap
        bboxes.append(span["bbox"])
    return bboxes

# %%
def union_bboxes(bboxes: List[Tuple[int,int,int,int]]) -> Tuple[int,int,int,int]:
    l = min(b[0] for b in bboxes)
    t = min(b[1] for b in bboxes)
    r = max(b[2] for b in bboxes)
    b = max(b[3] for b in bboxes)
    return (l, t, r, b)

def redact_boxes(img: Image.Image, boxes: List[Tuple[int,int,int,int]], margin: int = 2) -> Image.Image:
    draw = ImageDraw.Draw(img)
    for (l,t,r,b) in boxes:
        draw.rectangle([l - margin, t - margin, r + margin, b + margin], fill="black")
    return img

def compute_sensitivity_score(events: List[RedactionEvent]) -> float:
    """
    Aggregate entity-level scores into a document sensitivity score in [0,1].
    Weighted by entity type importance (tunable); default weights approximate risk.
    """
    if not events:
        return 0.0
    weights = {
        "PER": 1.0, "PERSON": 1.0,
        "ORG": 0.8, "ORGANIZATION": 0.8,
        "LOC": 0.6, "LOCATION": 0.6,
        "GPE": 0.6,
        "DATE": 0.4, "TIME": 0.4,
        "NORP": 0.5, "MISC": 0.5,
        "EMAIL": 0.9, "EMAIL_ADDRESS": 0.9,
        "PHONE_NUMBER": 0.9, "CARDINAL": 0.5,
        "MONEY": 0.8, "CREDIT_CARD": 1.0, "ACCOUNT_NUMBER": 1.0,
        # add other domain-specific tags as needed
    }
    total = 0.0
    denom = 0.0
    for e in events:
        w = weights.get(e.label, 0.7)  # default mid-high weight
        total += w * e.score
        denom += w
    score = total / max(denom, 1e-6)
    # Normalize gently to emphasize high-risk presence
    return min(1.0, max(0.0, score))

def label_sensitivity(score: float) -> str:
    if score >= 0.85:
        return "HIGH"
    elif score >= 0.6:
        return "MEDIUM"
    elif score >= 0.3:
        return "LOW"
    else:
        return "PUBLIC"

# %%
def process_image(
    img: Image.Image,
    ner_pipe,
    threshold: float = 0.85,
    ocr_lang: str = "eng",
) -> Tuple[Image.Image, List[RedactionEvent]]:
    """
    OCR + NER on a single image. Returns redacted image and list of events.
    """
    words = ocr_image_words(img, lang=ocr_lang)
    lines = words_to_lines(words)
    events: List[RedactionEvent] = []
    draw_boxes: List[Tuple[int,int,int,int]] = []

    for line in lines:
        text = line["text"]
        if not text.strip():
            continue
        entities = ner_pipe(text)  # [{'entity_group': 'PER', 'score': 0.99, 'word': 'John', 'start': 0, 'end': 4}, ...]
        for ent in entities:
            score = float(ent.get("score", 0.0))
            if score < threshold:
                continue
            bboxes = align_entity_to_bboxes(ent, line)
            if not bboxes:
                continue
            union = union_bboxes(bboxes)
            draw_boxes.append(union)
            events.append(RedactionEvent(
                page_index=0,  # to be overwritten by caller for PDFs
                text=text[ent["start"]:ent["end"]],
                label=str(ent.get("entity_group", ent.get("entity", "ENTITY"))),
                score=score,
                bbox=union,
                line_index=line["line_index"]
            ))
    # Draw redactions
    redacted = img.copy()
    redact_boxes(redacted, draw_boxes)
    return redacted, events

# %%
def save_pdf_from_images(images: List[Image.Image], out_path: Path):
    # Ensure all images are RGB
    images_rgb = [im.convert("RGB") for im in images]
    if len(images_rgb) == 1:
        images_rgb[0].save(out_path, "PDF", resolution=200.0)
    else:
        images_rgb[0].save(out_path, "PDF", resolution=200.0, save_all=True, append_images=images_rgb[1:])

# %%
def write_logs(events: List[RedactionEvent], summary: DocumentSummary, out_dir: Path, base_name: str):
    # JSON
    json_path = out_dir / f"{base_name}_redaction_log.json"
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump([asdict(e) for e in events], f, indent=2)

    # CSV
    csv_path = out_dir / f"{base_name}_redaction_log.csv"
    with open(csv_path, "w", encoding="utf-8", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["page_index", "line_index", "label", "score", "text", "bbox_left", "bbox_top", "bbox_right", "bbox_bottom"])
        for e in events:
            l, t, r, b = e.bbox
            writer.writerow([e.page_index, e.line_index, e.label, f"{e.score:.4f}", e.text, l, t, r, b])

    # Summary
    summary_path = out_dir / f"{base_name}_summary.json"
    with open(summary_path, "w", encoding="utf-8") as f:
        json.dump(asdict(summary), f, indent=2)

# %%
def process_file(input_path: Path, output_dir: Path, threshold: float, model_name: str, ocr_lang: str):
    output_dir.mkdir(parents=True, exist_ok=True)
    ner_pipe = load_ner_pipeline(model_name=model_name)

    ext = input_path.suffix.lower()
    redaction_events: List[RedactionEvent] = []
    redacted_images: List[Image.Image] = []
    total_pages = 0

    if ext == ".pdf":
        page_images = pdf_to_images(input_path, dpi=200)
        total_pages = len(page_images)
        for i, page_img in enumerate(page_images):
            red_img, events = process_image(page_img, ner_pipe, threshold=threshold, ocr_lang=ocr_lang)
            # set page_index on events
            for e in events:
                e.page_index = i
            redacted_images.append(red_img)
            redaction_events.extend(events)

        # Save redacted PDF
        base_name = input_path.stem + "_REDACTED"
        out_pdf = output_dir / f"{base_name}.pdf"
        save_pdf_from_images(redacted_images, out_pdf)

    elif ext in SUPPORTED_IMAGE_EXTS:
        total_pages = 1
        img = load_image_any(input_path)
        red_img, events = process_image(img, ner_pipe, threshold=threshold, ocr_lang=ocr_lang)
        for e in events:
            e.page_index = 0
        redaction_events.extend(events)
        # Save redacted image (same format as input)
        base_name = input_path.stem + "_REDACTED"
        out_img = output_dir / f"{base_name}{ext}"
        red_img.save(out_img)

    else:
        raise ValueError(f"Unsupported file type: {ext}")

    # Compute sensitivity
    sens_score = compute_sensitivity_score(redaction_events)
    sens_label = label_sensitivity(sens_score)

    # Write logs
    base_name_core = input_path.stem
    summary = DocumentSummary(
        input_path=str(input_path),
        total_pages=total_pages,
        total_entities=len(redaction_events),
        redacted_entities=len(redaction_events),
        sensitivity_score=sens_score,
        sensitivity_label=sens_label,
        threshold=threshold,
        model_name=model_name,
        generated_at=datetime.utcnow().isoformat() + "Z",
    )
    write_logs(redaction_events, summary, output_dir, base_name_core)

    return summary

# %%
import torch
import sys
import json
from pathlib import Path
from transformers import pipeline


def main(input_file, output_dir, threshold=0.85, model_name="dslim/bert-base-NER", ocr_lang="eng"):
    print("🚀 Running AI Shredder++")
    print(f"Input file     : {input_file}")
    print(f"Output folder  : {output_dir}")
    print(f"Confidence thr : {threshold}")

    # Convert strings → Path objects
    input_path = Path(input_file)
    output_path = Path(output_dir)

    if not input_path.exists():
        print(f"❌ Input file not found: {input_path}", file=sys.stderr)
        sys.exit(1)

    # Ensure output directory exists
    output_path.mkdir(parents=True, exist_ok=True)

    try:
        summary = process_file(
            input_path,
            output_path,
            threshold=threshold,
            model_name=model_name,
            ocr_lang=ocr_lang
        )
        print(json.dumps(asdict(summary), indent=2))
        print(f"\n✅ Redaction complete. Files saved to: {output_path}")
    except Exception as e:
      print(f"❌ Error: {e}", file=sys.stderr)
      return

# %%
from dataclasses import asdict

# %%
import os
from pathlib import Path

# ---- Modified main() ----
def main(input_file, output_dir, threshold=0.9):
    print("🚀 Running AI Shredder++")
    print(f"Input file     : {input_file}")
    print(f"Output folder  : {output_dir}")
    print(f"Confidence thr : {threshold}")

    # --- your existing code goes here ---
    # Example: load image, run OCR/NER model, redact sensitive entities
    # Let's assume you collect all detected entities in a list
    detected_entities = []  

    # TODO: Replace this dummy example with your actual detection logic
    # Example: detected_entities = ner_model(image, threshold)
    # cv2.imwrite(output_path, redacted_image)

    # For now assume we simulate: found 3 entities
    # (Remove this line when your actual pipeline is there)
    detected_entities = ["Name", "Date", "AccountNumber"]

    entities_found = len(detected_entities)

    # ---- Save your redacted image as before ----
    # output_path = os.path.join(output_dir, Path(input_file).name)
    # cv2.imwrite(output_path, redacted_image)

    return entities_found   # ✅ Now returns integer


# ---- Batch Processing with Stats ----
input_folder = Path("budget/budget")
output_folder = Path("budget/redacted")
output_folder.mkdir(parents=True, exist_ok=True)

exts = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp", ".webp"}

# Stats
total_images = 0
total_entities = 0
redacted_images = 0

for img_path in input_folder.iterdir():
    if img_path.suffix.lower() in exts:
        total_images += 1

        print(f"\nRedacting: {img_path}")
        entities_found = main(
            input_file=str(img_path),
            output_dir=str(output_folder),
            threshold=0.9
        ) or 0   # fallback: if None, treat as 0

        if entities_found > 0:
            redacted_images += 1
            total_entities += entities_found

# ---- SUMMARY ----
print("\n📊 SUMMARY REPORT")
print(f"Total Images Processed     : {total_images}")
print(f"Images with Redactions     : {redacted_images}")
print(f"Total Entities Redacted    : {total_entities}")
if total_images > 0:
    print(f"Avg Entities per Image     : {total_entities / total_images:.2f}")
    print(f"Redaction Coverage (%)     : {100 * redacted_images / total_images:.2f}%")
# Out:
# Redacting: budget\budget\0000009955.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000009955.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000009994.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000009994.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000011675.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000011675.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000011677.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000011677.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000016462.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000016462.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000016526.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000016526.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000016545.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000016545.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000022275.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000022275.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000031613.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000031613.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00000334.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00000334.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00000337.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00000337.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00000364.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00000364.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00000376.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00000376.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000037987.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000037987.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000045655.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000045655.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000049685.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000049685.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000076288.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000076288.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000076314.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000076314.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000076354.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000076354.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000076403.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000076403.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000076449.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000076449.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000079198.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000079198.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000079568.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000079568.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000086891.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000086891.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000090363.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000090363.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000090961.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000090961.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000091958.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000091958.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000092147.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000092147.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000094666.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000094666.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000105727.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000105727.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000106414.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000106414.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00001074.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00001074.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000108293.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000108293.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000110553.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000110553.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000113681.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000113681.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000115273.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000115273.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000115284.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000115284.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000115300.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000115300.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000116109.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000116109.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000116873.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000116873.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000118509.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000118509.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000119279.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000119279.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000119326.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000119326.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000121599.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000121599.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000123103.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000123103.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000128637.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000128637.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000129172.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000129172.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000134410.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000134410.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000144185.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000144185.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00001486.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00001486.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000153444.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000153444.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000167242.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000167242.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000167320.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000167320.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000168392.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000168392.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000169342.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000169342.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000169657.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000169657.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000170242.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000170242.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000170377.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000170377.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000171539.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000171539.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000171896.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000171896.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000172394.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000172394.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000172417.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000172417.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000174425.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000174425.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000175790.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000175790.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000175793.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000175793.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000187263.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000187263.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000193420.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000193420.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000202042.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000202042.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000202914.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000202914.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000203549.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000203549.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000208053.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000208053.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000211931.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000211931.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000219075.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000219075.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000219143.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000219143.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000219174.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000219174.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000219198.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000219198.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000221094.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000221094.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000222768.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000222768.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000223148.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000223148.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000223905.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000223905.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000227148.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000227148.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000231274.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000231274.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000231277.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000231277.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000231887.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000231887.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000238893.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000238893.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000238898.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000238898.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000238916.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000238916.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000238965.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000238965.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000242168.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000242168.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000247024.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000247024.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000247188.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000247188.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000252849.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000252849.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253108.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253108.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253110.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253110.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253142.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253142.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253596.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253596.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253678.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253678.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253705.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253705.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253730.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253730.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000253803.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000253803.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000254573.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000254573.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000257184.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000257184.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000257240.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000257240.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000261012.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000261012.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000261022.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000261022.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000261032.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000261032.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000261037.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000261037.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000263971.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000263971.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000267018.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000267018.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000278514.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000278514.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000279365.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000279365.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000280876.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000280876.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000300426.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000300426.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000337606.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000337606.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000337800.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000337800.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000338975.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000338975.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000338983.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000338983.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000339439.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000339439.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000339789.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000339789.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000340011.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000340011.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000341878.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000341878.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000352332.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000352332.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000352911.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000352911.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000352915.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000352915.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000358598.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000358598.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000368776.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000368776.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000374314.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000374314.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000391667.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000391667.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000391719.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000391719.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000391736.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000391736.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000392657.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000392657.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000394666.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000394666.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000399823.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000399823.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000399840.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000399840.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000399885.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000399885.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000400098.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000400098.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000400100.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000400100.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000400173.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000400173.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000400265.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000400265.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000405312.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000405312.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000405607.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000405607.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000414809.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000414809.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000414820.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000414820.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000415432.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000415432.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000431577.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000431577.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000431593.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000431593.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00004335_00004336.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00004335_00004336.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000434683.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000434683.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000435201.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000435201.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000435437.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000435437.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000435491.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000435491.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000435779.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000435779.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000435871.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000435871.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000436292.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000436292.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000437470.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000437470.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000437618.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000437618.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000438877.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000438877.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000438888.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000438888.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000443041.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000443041.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000443095.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000443095.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000443338.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000443338.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000443344.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000443344.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000443345.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000443345.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000444243.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000444243.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000444797.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000444797.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000447575.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000447575.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000450429.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000450429.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000451619.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000451619.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000452392.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000452392.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000452892.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000452892.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000471951.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000471951.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000507160.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000507160.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000507867.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000507867.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000511830.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000511830.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000537622.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000537622.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000538523.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000538523.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000540403.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000540403.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000540448.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000540448.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000541749.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000541749.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000542782.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000542782.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000543703.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000543703.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000544008.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000544008.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000544379.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000544379.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000545104.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000545104.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000545670.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000545670.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000565982.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000565982.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000642437.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000642437.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000642921.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000642921.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000711684.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000711684.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0000716939.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0000716939.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0001058137.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0001058137.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00044040_00044042.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00044040_00044042.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013008554.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013008554.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013040250.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013040250.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013040252.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013040252.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013040273.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013040273.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013043441.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013043441.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\0013044549.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\0013044549.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\00920055.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\00920055.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01001803_01001804.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01001803_01001804.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01002561.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01002561.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01322685.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01322685.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01322701.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01322701.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01322728.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01322728.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01322734.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01322734.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01322745.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01322745.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01338329.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01338329.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01340821.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01340821.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01391512.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01391512.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01391513.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01391513.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01391518.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01391518.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01408991.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01408991.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01408999.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01408999.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409385.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409385.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409447.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409447.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409468.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409468.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409488.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409488.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409494.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409494.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409495.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409495.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409505.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409505.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409515.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409515.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409516.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409516.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409569.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409569.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409669.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409669.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409856.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409856.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409872.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409872.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01409894.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01409894.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01410045.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01410045.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01410420.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01410420.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01410567.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01410567.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01410649.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01410649.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\01680664_01680699.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\01680664_01680699.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03001773_03001777.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03001773_03001777.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03008160_03008163.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03008160_03008163.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03056253_03056254.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03056253_03056254.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03064866.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03064866.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03079554_9555.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03079554_9555.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03155193.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03155193.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03195877.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03195877.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03659405_03659413.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03659405_03659413.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03660617.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03660617.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03662019_03662026.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03662019_03662026.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03662331_03662337.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03662331_03662337.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03662338.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03662338.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03724472_03724473.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03724472_03724473.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03724809.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03724809.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03747338_03747342.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03747338_03747342.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\03749673.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\03749673.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002115.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002115.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002295_04002311.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002295_04002311.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002400_04002401.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002400_04002401.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002541.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002541.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002591.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002591.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002625.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002625.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002682.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002682.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002697.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002697.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002714.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002714.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002755_04002756.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002755_04002756.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002788_04002789.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002788_04002789.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002796_04002797.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002796_04002797.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04002905.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04002905.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003103.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003103.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003104.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003104.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003142.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003142.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003207.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003207.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003263.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003263.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003308.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003308.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003340.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003340.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04003378.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04003378.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04103536_04103662.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04103536_04103662.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04162084.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04162084.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04238597.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04238597.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04238684.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04238684.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04238734.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04238734.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04239134.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04239134.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04239201.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04239201.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04239292.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04239292.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04239444.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04239444.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04329819_9820.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04329819_9820.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\04400171_04400188.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\04400171_04400188.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005205.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005205.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005346.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005346.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005387.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005387.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005401.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005401.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005412.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005412.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005419.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005419.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005429.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005429.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005435.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005435.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005450.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005450.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005479.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005479.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\09005572.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\09005572.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# ...
# Input file     : budget\budget\tob08108.78_tob08108.79.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08108.94.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08108.94.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08109.14.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08109.14.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08109.22_tob08109.23.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08109.22_tob08109.23.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08109.85.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08109.85.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08110.66.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08110.66.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08113.21.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08113.21.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08213.06.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08213.06.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08217.58.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08217.58.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08217.60.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08217.60.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08218.99.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08218.99.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08220.46.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08220.46.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08220.60.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08220.60.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08220.63.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08220.63.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08225.80.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08225.80.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08322.99.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08322.99.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08810.29.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08810.29.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob08817.83.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob08817.83.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob09518.37.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob09518.37.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob09922.80.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob09922.80.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob10413.54.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob10413.54.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob11003.33.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob11003.33.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob11102.69_tob11102.70.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob11102.69_tob11102.70.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob11117.34_tob11117.39.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob11117.34_tob11117.39.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob11130.68_tob11130.69.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob11130.68_tob11130.69.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob12623.88.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob12623.88.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13617.02.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13617.02.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13708.65.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13708.65.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13708.94_tob13709.08.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13708.94_tob13709.08.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13710.09_tob13710.12.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13710.09_tob13710.12.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13712.14_tob13712.26.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13712.14_tob13712.26.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13712.74.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13712.74.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13713.08.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13713.08.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13713.21.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13713.21.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob13714.20_tob13714.25.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob13714.20_tob13714.25.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob14030.18_tob14030.21.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob14030.18_tob14030.21.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob14726.51_tob14726.52.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob14726.51_tob14726.52.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob15117.52_tob15117.57.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob15117.52_tob15117.57.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob15621.93_tob15622.03.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob15621.93_tob15622.03.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob16425.30.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob16425.30.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob16903.74_tob16904.01.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob16903.74_tob16904.01.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob16912.42_tob16912.98.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob16912.42_tob16912.98.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob17400.64.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob17400.64.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18624.14.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18624.14.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18708.52.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18708.52.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18708.59.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18708.59.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18710.03.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18710.03.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18902.69.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18902.69.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob18902.71.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob18902.71.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob19007.79.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob19007.79.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\tob19011.16.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\tob19011.16.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton00321.35_ton00321.36.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton00321.35_ton00321.36.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01509.08.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01509.08.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01509.13.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01509.13.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01623.90.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01623.90.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01702.76_ton01702.78.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01702.76_ton01702.78.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01702.80_ton01702.82.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01702.80_ton01702.82.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01802.40.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01802.40.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01909.32_ton01909.33.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01909.32_ton01909.33.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01920.33.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01920.33.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton01929.30_ton01929.52.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton01929.30_ton01929.52.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton02208.81_ton02208.82.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton02208.81_ton02208.82.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton02208.86_ton02208.87.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton02208.86_ton02208.87.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03004.25.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03004.25.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03005.43.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03005.43.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03412.03.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03412.03.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03413.01.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03413.01.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03413.04.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03413.04.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03505.99_ton03506.00.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03505.99_ton03506.00.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03509.19_ton03509.27.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03509.19_ton03509.27.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03512.55_ton03512.61.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03512.55_ton03512.61.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03520.17.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03520.17.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03708.83.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03708.83.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03709.02.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03709.02.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton03709.21.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton03709.21.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04002.50.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04002.50.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04101.51.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04101.51.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04104.14.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04104.14.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04114.42.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04114.42.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04114.51.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04114.51.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04114.58.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04114.58.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04217.66_ton04217.82.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04217.66_ton04217.82.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04407.32.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04407.32.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04808.46.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04808.46.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04810.05.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04810.05.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04824.22_ton04824.24.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04824.22_ton04824.24.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04903.27.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04903.27.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04903.35.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04903.35.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton04907.15_ton04907.16.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton04907.15_ton04907.16.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton05006.37.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton05006.37.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# Redacting: budget\budget\ton05110.06.tif
# 🚀 Running AI Shredder++
# Input file     : budget\budget\ton05110.06.tif
# Output folder  : budget\redacted
# Confidence thr : 0.9
#
# 📊 SUMMARY REPORT
# Total Images Processed     : 2506
# Images with Redactions     : 2506
# Total Entities Redacted    : 7518
# Avg Entities per Image     : 3.00
# Redaction Coverage (%)     : 100.00%

# %%
pip install PyPDF2 fpdf pdfplumber
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.0.1)
# Requirement already satisfied: fpdf in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.7.2)
# Requirement already satisfied: pdfplumber in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.11.7)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pdfminer.six==20250506->pdfplumber) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pdfminer.six==20250506->pdfplumber) (45.0.7)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.23)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
import os
from pathlib import Path
from PIL import Image, ImageDraw
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
from dataclasses import dataclass, asdict
import pytesseract
from pytesseract import Output
import fitz # PyMuPDF
from fpdf import FPDF
from PyPDF2 import PdfReader, PdfWriter
import csv
from datetime import datetime
from collections import defaultdict
from typing import List, Dict, Any, Tuple

# --- Data Classes from original notebook ---
@dataclass
class RedactionEvent:
    page_index: int
    text: str
    label: str
    score: float
    bbox: Tuple[int, int, int, int]
    line_index: int

@dataclass
class DocumentSummary:
    input_path: str
    total_pages: int
    total_entities: int
    redacted_entities: int
    sensitivity_score: float
    sensitivity_label: str
    threshold: float
    model_name: str
    generated_at: str

# --- Helper functions from original notebook (functional versions) ---
def load_ner_pipeline(model_name: str = "dslim/bert-base-NER"):
    # This is the correct pipeline loading from your original code.
    return pipeline("token-classification", model=model_name, aggregation_strategy="simple")

def ocr_image_words(img: Image.Image, lang: str = "eng") -> List[Dict[str, Any]]:
    """
    OCR an image and return a list of word dictionaries including:
      - text, conf, left, top, width, height, line_num
    """
    data = pytesseract.image_to_data(img, lang=lang, output_type=Output.DICT)
    n = len(data["text"])
    words = []
    for i in range(n):
        text = data["text"][i]
        if text is None or text.strip() == "":
            continue
        try:
            conf = float(data["conf"][i])
        except (ValueError, TypeError):
            conf = -1.0
        word = {
            "text": text,
            "conf": conf,
            "left": int(data["left"][i]),
            "top": int(data["top"][i]),
            "width": int(data["width"][i]),
            "height": int(data["height"][i]),
            "line_num": int(data.get("line_num", [0]*n)[i]),
            "block_num": int(data.get("block_num", [0]*n)[i]),
            "par_num": int(data.get("par_num", [0]*n)[i]),
        }
        words.append(word)
    return words

def words_to_lines(words: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Group words by their line_num, preserve order by x-position.
    """
    groups = defaultdict(list)
    for w in words:
        key = (w["block_num"], w["par_num"], w["line_num"])
        groups[key].append(w)

    lines = []
    for idx, (key, ws) in enumerate(sorted(groups.items(), key=lambda kv: (kv[0][0], kv[0][1], kv[0][2]))):
        ws_sorted = sorted(ws, key=lambda x: x["left"])
        text_parts = []
        spans = []
        cursor = 0
        for w in ws_sorted:
            word_text = str(w["text"])
            if text_parts:
                text_parts.append(" ")
                cursor += 1
            start = cursor
            text_parts.append(word_text)
            cursor += len(word_text)
            end = cursor
            bbox = (w["left"], w["top"], w["left"] + w["width"], w["top"] + w["height"])
            spans.append({
                "text": word_text,
                "bbox": bbox,
                "start_char": start,
                "end_char": end,
                "conf": w["conf"],
            })
        lines.append({
            "line_index": idx,
            "text": "".join(text_parts),
            "spans": spans
        })
    return lines

def align_entity_to_bboxes(entity: Dict[str, Any], line: Dict[str, Any]) -> List[Tuple[int,int,int,int]]:
    """
    Aligns NER entity character offsets to OCR word bounding boxes.
    """
    start = entity["start"]
    end = entity["end"]
    bboxes = []
    for span in line["spans"]:
        if span["end_char"] <= start or span["start_char"] >= end:
            continue
        bboxes.append(span["bbox"])
    return bboxes

def union_bboxes(bboxes: List[Tuple[int,int,int,int]]) -> Tuple[int,int,int,int]:
    """Combines a list of bounding boxes into a single, encompassing box."""
    if not bboxes:
        return None
    l = min(b[0] for b in bboxes)
    t = min(b[1] for b in bboxes)
    r = max(b[2] for b in bboxes)
    b = max(b[3] for b in bboxes)
    return (l, t, r, b)

def redact_boxes(img: Image.Image, boxes: List[Tuple[int,int,int,int]], margin: int = 2) -> Image.Image:
    """Draws black rectangles over specified bounding boxes."""
    draw = ImageDraw.Draw(img)
    if boxes:
        for (l,t,r,b) in boxes:
            draw.rectangle([l - margin, t - margin, r + margin, b + margin], fill="black")
    return img

def compute_sensitivity_score(events: List[RedactionEvent]) -> float:
    """Calculates a document sensitivity score based on entity weights."""
    if not events:
        return 0.0
    weights = {
        "PER": 1.0, "PERSON": 1.0,
        "ORG": 0.8, "ORGANIZATION": 0.8,
        "LOC": 0.6, "LOCATION": 0.6,
        "GPE": 0.6,
        "DATE": 0.4, "TIME": 0.4,
        "NORP": 0.5, "MISC": 0.5,
        "EMAIL": 0.9, "EMAIL_ADDRESS": 0.9,
        "PHONE_NUMBER": 0.9, "CARDINAL": 0.5,
        "MONEY": 0.8, "CREDIT_CARD": 1.0, "ACCOUNT_NUMBER": 1.0,
    }
    total = 0.0
    denom = 0.0
    for e in events:
        w = weights.get(e.label, 0.7)
        total += w * e.score
        denom += w
    score = total / max(denom, 1e-6)
    return min(1.0, max(0.0, score))

def label_sensitivity(score: float) -> str:
    """Assigns a label based on the sensitivity score."""
    if score >= 0.85:
        return "HIGH"
    elif score >= 0.6:
        return "MEDIUM"
    else:
        return "LOW"

# --- Main script logic to process images and generate a summary report ---
def process_image_and_classify(img_path: Path, output_dir: Path, ner_pipe, threshold: float = 0.9):
    """
    Orchestrates the image processing, classification, and redaction.
    Returns classification and number of entities redacted.
    """
    img = Image.open(img_path).convert("RGB")
    words = ocr_image_words(img)
    lines = words_to_lines(words)
    redaction_events = []
    draw_boxes = []

    for line in lines:
        text = line["text"]
        if not text.strip():
            continue
        entities = ner_pipe(text)
        for ent in entities:
            score = float(ent.get("score", 0.0))
            if score < threshold:
                continue
            bboxes = align_entity_to_bboxes(ent, line)
            if not bboxes:
                continue
            union_bbox = union_bboxes(bboxes)
            draw_boxes.append(union_bbox)
            redaction_events.append(RedactionEvent(
                page_index=0,
                text=text[ent["start"]:ent["end"]],
                label=str(ent.get("entity_group", ent.get("entity", "ENTITY"))),
                score=score,
                bbox=union_bbox,
                line_index=line["line_index"]
            ))

    sens_score = compute_sensitivity_score(redaction_events)
    classification = label_sensitivity(sens_score)
    
    # Redact and save the image if not LOW
    if classification in ["MEDIUM", "HIGH"]:
        redacted_img = img.copy()
        redact_boxes(redacted_img, draw_boxes)
        output_path = output_dir / img_path.name
        redacted_img.save(output_path)
    
    return classification, len(redaction_events)

# --- Batch Processing and Final Summary Report ---
def run_redaction_and_summary(input_folder, output_folder, threshold=0.9):
    output_folder.mkdir(parents=True, exist_ok=True)
    ner_pipe = load_ner_pipeline()
    image_extensions = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp", ".webp"}

    # Stats counters
    classification_counts = {"LOW": 0, "MEDIUM": 0, "HIGH": 0}
    total_images_processed = 0
    total_redacted_entities = 0

    print("🚀 Starting image redaction and classification...")
    
    for img_file in input_folder.iterdir():
        if img_file.suffix.lower() in image_extensions:
            try:
                classification, entity_count = process_image_and_classify(
                    img_file, output_folder, ner_pipe, threshold=threshold
                )
                
                total_images_processed += 1
                total_redacted_entities += entity_count
                
                # Update classification counts
                classification_counts[classification] += 1
            
            except Exception as e:
                print(f"Error processing {img_file.name}: {e}")

    # --- Final Summary Report ---
    print("\n📊 FINAL CLASSIFICATION SUMMARY REPORT")
    print(f"Total Images Processed      : {total_images_processed}")
    print(f"Images Classified as LOW    : {classification_counts['LOW']}")
    print(f"Images Classified as MEDIUM : {classification_counts['MEDIUM']}")
    print(f"Images Classified as HIGH   : {classification_counts['HIGH']}")
    print(f"Total Entities Redacted     : {total_redacted_entities}")
    if total_images_processed > 0:
        print(f"Avg Entities per Image      : {total_redacted_entities / total_images_processed:.2f}")
    
# --- Execution block (you would uncomment this to run) ---
input_folder = Path("budget/budget")
output_folder = Path("budget/classification")
run_redaction_and_summary(input_folder, output_folder)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# 🚀 Starting image redaction and classification...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 265
#     263 input_folder = Path("budget/budget")
#     264 output_folder = Path("budget/classification")
# --> 265 run_redaction_and_summary(input_folder, output_folder)
#
# Cell In[57], line 239, in run_redaction_and_summary(input_folder, output_folder, threshold)
#     237 if img_file.suffix.lower() in image_extensions:
#     238     try:
# --> 239         classification, entity_count = process_image_and_classify(
#     240             img_file, output_folder, ner_pipe, threshold=threshold
#     241         )
#     243         total_images_processed += 1
#     244         total_redacted_entities += entity_count
#
# Cell In[57], line 192, in process_image_and_classify(img_path, output_dir, ner_pipe, threshold)
#     190 if not text.strip():
#     191     continue
# --> 192 entities = ner_pipe(text)
#     193 for ent in entities:
#     194     score = float(ent.get("score", 0.0))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\token_classification.py:279, in TokenClassificationPipeline.__call__(self, inputs, **kwargs)
#     276 if offset_mapping:
#     277     kwargs["offset_mapping"] = offset_mapping
# --> 279 return super().__call__(inputs, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\base.py:1450, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1448     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1449 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1450     return next(
#    1451         iter(
#    1452             self.get_iterator(
#    1453                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1454             )
#    1455         )
#    1456     )
#    1457 else:
#    1458     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\pt_utils.py:269, in PipelinePackIterator.__next__(self)
#     266             return accumulator
#     268 while not is_last:
# --> 269     processed = self.infer(next(self.iterator), **self.params)
#     270     if self.loader_batch_size is not None:
#     271         if isinstance(processed, torch.Tensor):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\base.py:1365, in Pipeline.forward(self, model_inputs, **forward_params)
#    1363     with inference_context():
#    1364         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1365         model_outputs = self._forward(model_inputs, **forward_params)
#    1366         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1367 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pipelines\token_classification.py:352, in TokenClassificationPipeline._forward(self, model_inputs)
#     350     logits = self.model(**model_inputs)[0]
#     351 else:
# --> 352     output = self.model(**model_inputs)
#     353     logits = output["logits"] if isinstance(output, dict) else output[0]
#     355 return {
#     356     "logits": logits,
#     357     "special_tokens_mask": special_tokens_mask,
#    (...)    363     **model_inputs,
#     364 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:1682, in BertForTokenClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1676 r"""
#    1677 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1678     Labels for computing the token classification loss. Indices should be in `[0, ..., config.num_labels - 1]`.
#    1679 """
#    1680 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1682 outputs = self.bert(
#    1683     input_ids,
#    1684     attention_mask=attention_mask,
#    1685     token_type_ids=token_type_ids,
#    1686     position_ids=position_ids,
#    1687     head_mask=head_mask,
#    1688     inputs_embeds=inputs_embeds,
#    1689     output_attentions=output_attentions,
#    1690     output_hidden_states=output_hidden_states,
#    1691     return_dict=return_dict,
#    1692 )
#    1694 sequence_output = outputs[0]
#    1696 sequence_output = self.dropout(sequence_output)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:1006, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     999 # Prepare head mask if needed
#    1000 # 1.0 in head_mask indicate we keep the head
#    1001 # attention_probs has shape bsz x n_heads x N x N
#    1002 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1003 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1004 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1006 encoder_outputs = self.encoder(
#    1007     embedding_output,
#    1008     attention_mask=extended_attention_mask,
#    1009     head_mask=head_mask,
#    1010     encoder_hidden_states=encoder_hidden_states,
#    1011     encoder_attention_mask=encoder_extended_attention_mask,
#    1012     past_key_values=past_key_values,
#    1013     use_cache=use_cache,
#    1014     output_attentions=output_attentions,
#    1015     output_hidden_states=output_hidden_states,
#    1016     return_dict=return_dict,
#    1017     cache_position=cache_position,
#    1018 )
#    1019 sequence_output = encoder_outputs[0]
#    1020 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:653, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     649     all_hidden_states = all_hidden_states + (hidden_states,)
#     651 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 653 layer_outputs = layer_module(
#     654     hidden_states,
#     655     attention_mask,
#     656     layer_head_mask,
#     657     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     658     encoder_attention_mask=encoder_attention_mask,
#     659     past_key_value=past_key_values,
#     660     output_attentions=output_attentions,
#     661     cache_position=cache_position,
#     662 )
#     664 hidden_states = layer_outputs[0]
#     665 if output_attentions:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:592, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, cache_position)
#     589     attention_output = cross_attention_outputs[0]
#     590     outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
# --> 592 layer_output = apply_chunking_to_forward(
#     593     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     594 )
#     595 outputs = (layer_output,) + outputs
#     597 return outputs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\pytorch_utils.py:251, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     248     # concatenate output at same dimension
#     249     return torch.cat(output_chunks, dim=chunk_dim)
# --> 251 return forward_fn(*input_tensors)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:601, in BertLayer.feed_forward_chunk(self, attention_output)
#     599 def feed_forward_chunk(self, attention_output):
#     600     intermediate_output = self.intermediate(attention_output)
# --> 601     layer_output = self.output(intermediate_output, attention_output)
#     602     return layer_output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bert\modeling_bert.py:530, in BertOutput.forward(self, hidden_states, input_tensor)
#     529 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 530     hidden_states = self.dense(hidden_states)
#     531     hidden_states = self.dropout(hidden_states)
#     532     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
